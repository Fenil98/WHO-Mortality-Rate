# %% [markdown]
# # Changelog
# This file contains the notable changes to the project for all 3 datasets.
#
#
# ## Country_code dataset
#
# ### Version 1.0.0 (04-6-2022)
#
# #### **New**
#
# Latitude and longitude added in 10 undefined countries. (Listed below)
# - Czechoslovakia, Former	50.0755° N, 14.4378° E
# - Germany, Former Democratic Republic 52.434° N, 12.5145° E
# - Germany, Former Federal Republic 51.1657° N, 10.4515° E
# - Netherlands Antilles	12.226079° N, -69.060087° E
# - Rodrigues	-19.7166638° N, 63.416665° E
# - United Kingdom, England and Wales	51.481583° N, -3.179090° E
# - United Kingdom, Northern Ireland	54.58598° N, -6.95916° E
# - United Kingdom, Scotland	56.78611° N, -4.11405° E
# - USSR, Former	55.659303° N, 39.848882° E
# - Yugoslavia, Former 44.818996724° N, 20.457331504° E
#
# #### **Changes**
# Removed **103** countries from total of **227** countries
#
# Changs in **name** column listed below
# - United Kingdom, Scotland to Scotland
# - United Kingdom, Northern Ireland to Northern Ireland
# - United Kingdom, England and Wales to England and Wales
#
#
#
# ## Pop dataset
#
# ### Version 1.0.0 (04-6-2022)
#
# #### **New**
# Nothing new added
#
# #### **Changes**
# Changed the **Year** column datatype from **numeric** to **Date**.
#
# Removed some countries from dataset. Initially there was **9913** rows but after operation there is only **9147** rows remaining.
#
#
# ## Morticd9 dataset
#
# ### Version 1.0.0 (04-6-2022)
#
# #### **New**
# Nothing new added
#
# #### **Changes**
# Changed the **Year** column datatype from **numeric** to **Date**.
#
# Removed some countries for which there was no population recorded in dataset. Initially there was **899471** rows but after operation there is only **890028** rows remaining.
#
#
#
# ## Pop dataset
#
# ### Version 1.0.1 (04-13-2022)
#
# #### **New**
# New **Sex_m_f** named column added.
#
# New **country_name** named column added.
#
# #### **Changes**
#
# Take down all the countries except **five**
# - Canada
# - United States of America
# - China
# - Russian Federation
# - Australia
#
# ## Morticd9 dataset
#
# ### Version 1.0.1 (04-13-2022)
#
# #### **New**
# New **Sex_m_f** named column added.
#
# New **country_name** named column added.
#
#
# #### **Changes**
# Take down all the countries except **five**
# - Canada
# - United States of America
# - China
# - Russian Federation
# - Australia
#
#
# ## Major change in version 2.0.0
#
# > We have removed dataset **country_code** and merge them with other two dataset
#
#
# ## Pop dataset
#
# ### Version 2.0.0 (04-14-2022)
#
# #### **New**
# Two new countries added in the dataset
# - Cuba
# - France
#
# #### **Changes**
# Columns named **Admin1**, **SubDiv** and **Pop26** removed as they were blank.
#
# We have filtered the **Year** as well from **1991** to **1997**.
#
# Took down the two countries from **five**.
# - China
# - Russian Federation
#
# ## Morticd9 dataset
#
# ### Version 2.0.0 (04-14-2022)
#
# #### **New**
# Two new countries added in the dataset
# - Cuba
# - France
#
#
# #### **Changes**
# Columns named **Admin1**, **SubDiv**, **Deaths24** and **Deaths25** removed as they were blank.
#
# We have filtered the **Year** as well from **1991** to **1997**.
#
# Took down the two countries from **five**
# - China
# - Russian Federation
